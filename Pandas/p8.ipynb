# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/home/rostya/AI_course/UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V7/03-Pandas/tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
int(str(12341234123456789)[-4:])
# Out:
# 6789

# %%
def last_four(num):
    """Возвращает последние 4 цифры"""
    return int(str(num)[-4:])

# %%
last_four(12121212121212433546)
# Out:
# 3546

# %%
df['last_four'] = df['CC Number'].apply(last_four)  # Получаем последние 4 цифры каждой колонки с картами

# %%
df['total_bill'].mean()  # Среднее значение
# Out:
# 19.78594262295082

# %%
def yelp(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$'*2
    else:
        return '$'*3

# %%
df['yelp'] = df['total_bill'].apply(yelp)

# %%
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
simple(2)
# Out:
# 4

# %%
df['total_bill'].apply(lambda num: num*2)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  last_four yelp
# 0  Christy Cunningham  3560325168603410    Sun2959       3410   $$
# 1      Douglas Tucker  4478071379779230    Sun4608       9230   $$
# 2      Travis Walters  6011812112971322    Sun4458       1322   $$
# 3    Nathaniel Harris  4676137647685994    Sun5260       5994   $$
# 4        Tonya Carter  4832732618637221    Sun2251       7221   $$

# %%
def quality(total_bill, tip):
    if tip / total_bill > 0.25:  # Если чаевые составляют более 25% суммы счета
        return 'Щедрые чаевые'
    else:
        return 'Обычные чаевые'

# %%
quality(16.99, 1.01)
# Out:
# 'Обычные чаевые'

# %%
df['quality'] = df[['total_bill', 'tip']].apply(lambda df: quality(df['total_bill'], df['tip']), axis = 1)

# %%
df.tail(13)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3              5.23
# 232       11.61  3.39    Male     No   Sat  Dinner     2              5.80
# 233       10.77  1.47    Male     No   Sat  Dinner     2              5.38
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# ...

# %%
df['quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  last_four yelp  \
# 0  Christy Cunningham  3560325168603410    Sun2959       3410   $$
# 1      Douglas Tucker  4478071379779230    Sun4608       9230   $$
# 2      Travis Walters  6011812112971322    Sun4458       1322   $$
# 3    Nathaniel Harris  4676137647685994    Sun5260       5994   $$
# 4        Tonya Carter  4832732618637221    Sun2251       7221   $$
#
#           quality
# 0  Обычные чаевые
# 1  Обычные чаевые
# 2  Обычные чаевые
# 3  Обычные чаевые
# 4  Обычные чаевые

# %%
import timeit

# %%
# этот фрагмент кода будет запускаться только один раз
setup = '''
import numpy as np
import pandas as pd
df = pd.read_csv('/home/rostya/AI_course/UNZIP_ME_FOR_NOTEBOOKS_ML_RUS_V7/03-Pandas/tips.csv')
def quality(total_bill,tip):
    if tip/total_bill  > 0.25:
        return "Generous"
    else:
        return "Other"
'''

# %%
# это фрагменты кода, для которых будет измеряться время выполнения
# (они будут выполняться много раз)
stmt_one = ''' # Добавление новой колонки через lambda
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
'''

stmt_two = ''' # Добавление новой колонки через np.vectorize
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'], df['tip'])
'''

# %%
timeit.timeit(setup=setup, stmt=stmt_one,number=10000)
# Out:
# 20.671497647999786

# %%
timeit.timeit(setup=setup, stmt=stmt_two,number=10000)
# Out:
# 1.7532306510001945

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.sort_values(['tip', 'size'], ascending=True)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df['total_bill'].idxmax()
# Out:
# 170

# %%
df['total_bill'].idxmin()
# Out:
# 67

# %%
df.iloc[df['total_bill'].idxmin()]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# Name: 67, dtype: object

# %%
df.corr(numeric_only=True)
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df['sex'].value_counts()  # Количество строк с мужчинами и с женщинами
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['day'].unique()  # Уникальные значения
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
df['day'].nunique()  # Количество уникальных значений
# Out:
# 4

# %%
len(df['day'].unique())
# Out:
# 4

# %%
df['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['sex'].replace(['Female', 'Male'], ['F', 'M'])  # Замена
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
mymap = {'Female': 'F', 'Male': 'M'}
mymap
# Out:
# {'Female': 'F', 'Male': 'M'}

# %%
df['sex'].map(mymap)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %%
df.duplicated()  # Проверка на дубликаты
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %%
simple_df = pd.DataFrame([1, 2, 2, 2], ['a', 'b', 'c', 'd'])

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
simple_df.drop_duplicates()  # Удаление дубликатов
# Out:
#    0
# a  1
# b  2

# %%
df['total_bill'].between(10, 20, inclusive='both')  # True если total_bill в пределах от 10 до 20
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'].between(10, 20, inclusive='both')]  # DataFrame
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.nlargest(10, 'tip')  # 10 строк с найбольшими значениями tip
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4              5.79
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3              9.39
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 239       29.03   5.92    Male     No   Sat  Dinner     3              9.68
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
#
#             Payer Name         CC Number Payment ID
# 170      Gregory Clark  5473850968388236    Sat1954
# ...

# %%
df.nsmallest(10, 'tip')  # 10 строк с найменьшими значениями tip
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07  1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75  1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25  1.00  Female     No   Sat  Dinner     1              7.25
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 75        10.51  1.25    Male     No   Sat  Dinner     2              5.26
# 135        8.51  1.25  Female     No  Thur   Lunch     2              4.26
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
#
#              Payer Name         CC Number Payment ID
# 67        Tiffany Brock  4359488526995267    Sat3455
# ...

# %%
df.sort_values('tip', ascending=False).iloc[0:2]
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.0  Male     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590

# %%
df.sort_values('tip', ascending=True).iloc[0:2]
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 236       12.60  1.0    Male    Yes  Sat  Dinner     2              6.30
#
#         Payer Name         CC Number Payment ID
# 67   Tiffany Brock  4359488526995267    Sat3455
# 236  Matthew Myers  3543676378973965    Sat5032

# %%
df.sample(5)  # 5 нефиксированных случайных строк из датафрейма
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 107       25.21  4.29    Male    Yes   Sat  Dinner     2             12.60
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4              5.13
# 172        7.25  5.15    Male    Yes   Sun  Dinner     2              3.62
# 215       12.90  1.10  Female    Yes   Sat  Dinner     2              6.45
# 138       16.00  2.00    Male    Yes  Thur   Lunch     2              8.00
#
#         Payer Name         CC Number Payment ID
# 107   Jason Mullen     4738781782868    Sat5196
# 204      Scott Kim  3570611756827620   Thur2160
# 172    Larry White    30432617123103    Sun9209
# 215   Jessica Owen     4726904879471    Sat6983
# 138  Jason Burgess  3561461821942363   Thur2710

# %%
df.sample(frac=0.1)  # 1/10 или 10% случайных строк из датафрейма
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 190       15.69  1.50    Male    Yes   Sun  Dinner     2              7.84
# 178        9.60  4.00  Female    Yes   Sun  Dinner     2              4.80
# 43         9.68  1.32    Male     No   Sun  Dinner     2              4.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 76        17.92  3.08    Male    Yes   Sat  Dinner     2              8.96
# 210       30.06  2.00    Male    Yes   Sat  Dinner     3             10.02
# 56        38.01  3.00    Male    Yes   Sat  Dinner     4              9.50
# 129       22.82  2.18    Male     No  Thur   Lunch     3              7.61
# 38        18.69  2.31    Male     No   Sat  Dinner     3              6.23
# 112       38.07  4.00    Male     No   Sun  Dinner     3             12.69
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# ...
